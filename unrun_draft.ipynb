# %% [markdown]
# <a href="https://colab.research.google.com/github/jineacantor-tech/Taguig-Flooding-Risk-Evaluator/blob/main/unrun_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================================
# SCRIPT 1: TAGUIG FLOODING RISK EVALUATOR
# ====================================================================

# Current water level of Laguna de Bay in meters (m)
laguna_water_level = 12.8

# Logic condition to check for flood alerts
if laguna_water_level >= 13.5:
    print("STATUS: CRITICAL ALERT!")
    print("Warning: High risk of coastal flooding in Taguig barangays.")
else:
    print("STATUS: NORMAL.")
    print("Water levels are within safe parameters along the shoreline.")
